# %%
import numpy as np

# %%
rolls=np.random.randint(1,7,size=10)
rolls
# Out:
# array([5, 6, 6, 6, 6, 6, 2, 1, 4, 2], dtype=int32)

# %%
rolls+10
# Out:
# array([15, 16, 16, 16, 16, 16, 12, 11, 14, 12], dtype=int32)

# %%
rolls*2
# Out:
# array([10, 12, 12, 12, 12, 12,  4,  2,  8,  4], dtype=int32)

# %%
rolls<=3
# Out:
# array([False, False, False, False, False, False,  True,  True, False,
#         True])

# %%
xlist=[[1,2],[3,4]]
x=np.asarray(xlist)
print(type(xlist))
x
# Out:
# <class 'list'>
# array([[1, 2],
#        [3, 4]])

# %%
x[1,-1]
# Out:
# np.int64(4)

# %%
nums = [4,2,-5,-1,6,-3]
nums=sorted(nums,key=lambda x: x**2)
nums
# Out:
# [-1, 2, -3, 4, -5, 6]

# %%
import torch
torch.manual_seed(0)
x=torch.randn(size=(2,4))
print(x)
# Out:
# tensor([[ 1.5410, -0.2934, -2.1788,  0.5684],
#         [-1.0845, -1.3986,  0.4033,  0.8380]])
